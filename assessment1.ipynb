# %% [markdown]
# <a href="https://colab.research.google.com/github/evelynhasama/AITDeepLearning/blob/main/assessment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# %%
# !wget https://www.cdc.gov/healthypets/images/pets/boy-playing-with-dog.jpg? -O play.jpg
# Out:
# --2023-02-09 17:52:05--  https://www.cdc.gov/healthypets/images/pets/boy-playing-with-dog.jpg?
# Resolving www.cdc.gov (www.cdc.gov)... 23.15.97.17, 2600:1413:b000:687::2461, 2600:1413:b000:69a::2461
# Connecting to www.cdc.gov (www.cdc.gov)|23.15.97.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 112276 (110K) [image/jpeg]
# Saving to: ‘play.jpg’
#
# play.jpg            100%[===================>] 109.64K  --.-KB/s    in 0.003s
#
# 2023-02-09 17:52:07 (32.4 MB/s) - ‘play.jpg’ saved [112276/112276]

# %%
play_img = Image.open("play.jpg",mode='r')
display(play_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=724x483 at 0x7F99E4AC5E80>

# %%
width, height = play_img.size

for x in range(width-30,width):
  for y in range(0, 30):
    play_img.putpixel((x, y), (0, 0, 0, 255))

# %%
display(play_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=724x483 at 0x7F99E4AC5E80>
