# %% [markdown]
# <a href="https://colab.research.google.com/github/evelynhasama/AITDeepLearning/blob/main/Evelyn_12_Anomaly_detection_AE_assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Anomaly detection with autoencoders
#
# In this notebook we you have to create a fully-connected neural network based autoencoder in order to detect credit card frauds. In the dataset there are 492 labeled frauds and 284807 normal transactions. First, let's download the dataset and unpack it (original source of the dataset: https://www.kaggle.com/mlg-ulb/creditcardfraud - before downloading the data please read and accept the licence of the original datasource):

# %%
# !wget https://www.deeplearningoktatas.hu/downloads/Anomaly/creditcardfraud.zip
# Out:
# --2023-05-10 19:34:11--  https://www.deeplearningoktatas.hu/downloads/Anomaly/creditcardfraud.zip
# Resolving www.deeplearningoktatas.hu (www.deeplearningoktatas.hu)... 91.227.138.51
# Connecting to www.deeplearningoktatas.hu (www.deeplearningoktatas.hu)|91.227.138.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69155632 (66M) [application/zip]
# Saving to: ‘creditcardfraud.zip’
#
# creditcardfraud.zip 100%[===================>]  65.95M  18.8MB/s    in 4.6s
#
# 2023-05-10 19:34:17 (14.4 MB/s) - ‘creditcardfraud.zip’ saved [69155632/69155632]

# %%
# %%capture
# !unzip creditcardfraud.zip

# %% [markdown]
# ## Imports
# Import the necessary modules:

# %%
import pandas as pd # 
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import regularizers
from sklearn import preprocessing 
from sklearn.metrics import mean_squared_error
np.random.seed(123)

# %% [markdown]
# ## Exercise 1: Reading and preparing the data
# Read the creditcard.csv into a Pandas Dataframe with the [read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) function.

# %%
df = pd.read_csv("creditcard.csv")

# %% [markdown]
# As the next step, select all the columns of the dataframe for the input X, but the "Class" column. And select the "Class" column for output Y. Make sure that both X and Y are two dimensional Numpy arrays.
#
# Hint:
# * you can use df.loc to select rows and columns from a dataframe
# * you can get the Numpy array of a Pandas object with .values, eg. df['myfeature'].values

# %%
df.head
# Out:
# <bound method NDFrame.head of             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]>

# %%
X = df.loc[:,"Time":"Amount"].values
Y = df['Class'].values

# %%
print("Shape of X:",X.shape)
print("Shape of Y:",Y.shape)
# Out:
# Shape of X: (284807, 30)
# Shape of Y: (284807,)

# %% [markdown]
# Let's standardize the data:

# %%
scaler = preprocessing.StandardScaler().fit(X)
X = scaler.transform(X)

# %% [markdown]
# ## Exercise 2: defining the autoencoder
# Let's define a model according to the following instructions:
# * the model's inputs and outputs should be the same as the number of X's features (columns)
# * the model should have 5 hidden layers, with 16-10-6-10-16 neurons in the hidden layers, respectively
# * all layers but the output should have tanh activation
# * the output layer should have linear activation

# %%
X[0].shape
# Out:
# (30,)

# %%
model = Sequential()
model.add(Dense(16, input_shape=(X.shape[1],), activation='tanh'))
model.add(Dense(10, activation='tanh'))
model.add(Dense(6, activation='tanh'))
model.add(Dense(10, activation='tanh'))
model.add(Dense(16, activation='tanh'))
model.add(Dense(X.shape[1], activation='linear'))

# %% [markdown]
# ## Exercise 3: define early stopping compile the model, and train it
# Please pay attention to the following details:
# * use EarlyStopping with patience 10 and this time monitor the training loss
# * do not define validation data
# * use mean squarred error loss function
# * both the input and output of the model should be X this time. (as we are "auto encoding" the input to the output)

# %%
patience = 10
es = EarlyStopping(monitor="loss", patience=patience, restore_best_weights=True,)
model.compile(loss='mse', optimizer='adam',metrics=['accuracy'])

# %%
history= model.fit(X, X, 
          epochs=1000,
          batch_size =32,
          callbacks=[es],
          verbose=2)
# Out:
# Epoch 1/1000
# 8901/8901 - 35s - loss: 0.7257 - accuracy: 0.2824 - 35s/epoch - 4ms/step
# Epoch 2/1000
# 8901/8901 - 28s - loss: 0.6311 - accuracy: 0.3472 - 28s/epoch - 3ms/step
# Epoch 3/1000
# 8901/8901 - 27s - loss: 0.5994 - accuracy: 0.3737 - 27s/epoch - 3ms/step
# Epoch 4/1000
# 8901/8901 - 28s - loss: 0.5710 - accuracy: 0.3846 - 28s/epoch - 3ms/step
# Epoch 5/1000
# 8901/8901 - 28s - loss: 0.5586 - accuracy: 0.3856 - 28s/epoch - 3ms/step
# Epoch 6/1000
# 8901/8901 - 27s - loss: 0.5485 - accuracy: 0.3884 - 27s/epoch - 3ms/step
# Epoch 7/1000
# 8901/8901 - 27s - loss: 0.5421 - accuracy: 0.3876 - 27s/epoch - 3ms/step
# Epoch 8/1000
# 8901/8901 - 27s - loss: 0.5377 - accuracy: 0.3877 - 27s/epoch - 3ms/step
# Epoch 9/1000
# 8901/8901 - 28s - loss: 0.5321 - accuracy: 0.3899 - 28s/epoch - 3ms/step
# Epoch 10/1000
# 8901/8901 - 27s - loss: 0.5251 - accuracy: 0.3947 - 27s/epoch - 3ms/step
# Epoch 11/1000
# 8901/8901 - 27s - loss: 0.5208 - accuracy: 0.3979 - 27s/epoch - 3ms/step
# Epoch 12/1000
# 8901/8901 - 27s - loss: 0.5182 - accuracy: 0.3987 - 27s/epoch - 3ms/step
# Epoch 13/1000
# 8901/8901 - 28s - loss: 0.5151 - accuracy: 0.4004 - 28s/epoch - 3ms/step
# Epoch 14/1000
# 8901/8901 - 27s - loss: 0.5135 - accuracy: 0.3992 - 27s/epoch - 3ms/step
# Epoch 15/1000
# 8901/8901 - 27s - loss: 0.5113 - accuracy: 0.3997 - 27s/epoch - 3ms/step
# Epoch 16/1000
# 8901/8901 - 27s - loss: 0.5101 - accuracy: 0.4008 - 27s/epoch - 3ms/step
# Epoch 17/1000
# 8901/8901 - 28s - loss: 0.5074 - accuracy: 0.4012 - 28s/epoch - 3ms/step
# Epoch 18/1000
# 8901/8901 - 27s - loss: 0.5054 - accuracy: 0.4026 - 27s/epoch - 3ms/step
# Epoch 19/1000
# 8901/8901 - 27s - loss: 0.5034 - accuracy: 0.4044 - 27s/epoch - 3ms/step
# Epoch 20/1000
# 8901/8901 - 27s - loss: 0.5018 - accuracy: 0.4055 - 27s/epoch - 3ms/step
# Epoch 21/1000
# 8901/8901 - 28s - loss: 0.5010 - accuracy: 0.4065 - 28s/epoch - 3ms/step
# Epoch 22/1000
# 8901/8901 - 27s - loss: 0.4996 - accuracy: 0.4069 - 27s/epoch - 3ms/step
# Epoch 23/1000
# 8901/8901 - 27s - loss: 0.4991 - accuracy: 0.4080 - 27s/epoch - 3ms/step
# Epoch 24/1000
# 8901/8901 - 27s - loss: 0.4986 - accuracy: 0.4073 - 27s/epoch - 3ms/step
# Epoch 25/1000
# 8901/8901 - 28s - loss: 0.4972 - accuracy: 0.4082 - 28s/epoch - 3ms/step
# Epoch 26/1000
# 8901/8901 - 27s - loss: 0.4968 - accuracy: 0.4085 - 27s/epoch - 3ms/step
# Epoch 27/1000
# 8901/8901 - 27s - loss: 0.4958 - accuracy: 0.4092 - 27s/epoch - 3ms/step
# Epoch 28/1000
# 8901/8901 - 27s - loss: 0.4967 - accuracy: 0.4087 - 27s/epoch - 3ms/step
# Epoch 29/1000
# 8901/8901 - 28s - loss: 0.4954 - accuracy: 0.4092 - 28s/epoch - 3ms/step
# Epoch 30/1000
# 8901/8901 - 27s - loss: 0.4944 - accuracy: 0.4100 - 27s/epoch - 3ms/step
# Epoch 31/1000
# 8901/8901 - 27s - loss: 0.4935 - accuracy: 0.4106 - 27s/epoch - 3ms/step
# Epoch 32/1000
# 8901/8901 - 27s - loss: 0.4932 - accuracy: 0.4098 - 27s/epoch - 3ms/step
# Epoch 33/1000
# 8901/8901 - 28s - loss: 0.4928 - accuracy: 0.4101 - 28s/epoch - 3ms/step
# Epoch 34/1000
# 8901/8901 - 27s - loss: 0.4925 - accuracy: 0.4096 - 27s/epoch - 3ms/step
# Epoch 35/1000
# 8901/8901 - 27s - loss: 0.4914 - accuracy: 0.4093 - 27s/epoch - 3ms/step
# Epoch 36/1000
# 8901/8901 - 27s - loss: 0.4883 - accuracy: 0.4136 - 27s/epoch - 3ms/step
# Epoch 37/1000
# 8901/8901 - 28s - loss: 0.4838 - accuracy: 0.4228 - 28s/epoch - 3ms/step
# Epoch 38/1000
# 8901/8901 - 27s - loss: 0.4796 - accuracy: 0.4327 - 27s/epoch - 3ms/step
# Epoch 39/1000
# 8901/8901 - 27s - loss: 0.4761 - accuracy: 0.4394 - 27s/epoch - 3ms/step
# Epoch 40/1000
# 8901/8901 - 27s - loss: 0.4748 - accuracy: 0.4427 - 27s/epoch - 3ms/step
# Epoch 41/1000
# 8901/8901 - 28s - loss: 0.4721 - accuracy: 0.4453 - 28s/epoch - 3ms/step
# Epoch 42/1000
# 8901/8901 - 27s - loss: 0.4707 - accuracy: 0.4456 - 27s/epoch - 3ms/step
# Epoch 43/1000
# 8901/8901 - 27s - loss: 0.4705 - accuracy: 0.4459 - 27s/epoch - 3ms/step
# Epoch 44/1000
# 8901/8901 - 28s - loss: 0.4694 - accuracy: 0.4467 - 28s/epoch - 3ms/step
# Epoch 45/1000
# 8901/8901 - 28s - loss: 0.4686 - accuracy: 0.4468 - 28s/epoch - 3ms/step
# Epoch 46/1000
# 8901/8901 - 27s - loss: 0.4676 - accuracy: 0.4469 - 27s/epoch - 3ms/step
# Epoch 47/1000
# 8901/8901 - 28s - loss: 0.4671 - accuracy: 0.4463 - 28s/epoch - 3ms/step
# Epoch 48/1000
# 8901/8901 - 28s - loss: 0.4675 - accuracy: 0.4461 - 28s/epoch - 3ms/step
# Epoch 49/1000
# 8901/8901 - 27s - loss: 0.4670 - accuracy: 0.4466 - 27s/epoch - 3ms/step
# Epoch 50/1000
# 8901/8901 - 27s - loss: 0.4668 - accuracy: 0.4454 - 27s/epoch - 3ms/step
# Epoch 51/1000
# 8901/8901 - 27s - loss: 0.4664 - accuracy: 0.4466 - 27s/epoch - 3ms/step
# Epoch 52/1000
# 8901/8901 - 28s - loss: 0.4667 - accuracy: 0.4468 - 28s/epoch - 3ms/step
# Epoch 53/1000
# 8901/8901 - 27s - loss: 0.4665 - accuracy: 0.4463 - 27s/epoch - 3ms/step
# Epoch 54/1000
# 8901/8901 - 27s - loss: 0.4658 - accuracy: 0.4471 - 27s/epoch - 3ms/step
# Epoch 55/1000
# 8901/8901 - 27s - loss: 0.4657 - accuracy: 0.4461 - 27s/epoch - 3ms/step
# Epoch 56/1000
# 8901/8901 - 28s - loss: 0.4654 - accuracy: 0.4461 - 28s/epoch - 3ms/step
# Epoch 57/1000
# 8901/8901 - 27s - loss: 0.4656 - accuracy: 0.4467 - 27s/epoch - 3ms/step
# Epoch 58/1000
# 8901/8901 - 27s - loss: 0.4651 - accuracy: 0.4464 - 27s/epoch - 3ms/step
# Epoch 59/1000
# 8901/8901 - 28s - loss: 0.4649 - accuracy: 0.4459 - 28s/epoch - 3ms/step
# Epoch 60/1000
# 8901/8901 - 28s - loss: 0.4649 - accuracy: 0.4462 - 28s/epoch - 3ms/step
# Epoch 61/1000
# 8901/8901 - 27s - loss: 0.4648 - accuracy: 0.4447 - 27s/epoch - 3ms/step
# Epoch 62/1000
# 8901/8901 - 27s - loss: 0.4643 - accuracy: 0.4459 - 27s/epoch - 3ms/step
# Epoch 63/1000
# 8901/8901 - 28s - loss: 0.4645 - accuracy: 0.4461 - 28s/epoch - 3ms/step
# Epoch 64/1000
# 8901/8901 - 28s - loss: 0.4645 - accuracy: 0.4470 - 28s/epoch - 3ms/step
# Epoch 65/1000
# 8901/8901 - 28s - loss: 0.4650 - accuracy: 0.4447 - 28s/epoch - 3ms/step
# Epoch 66/1000
# 8901/8901 - 28s - loss: 0.4640 - accuracy: 0.4459 - 28s/epoch - 3ms/step
# Epoch 67/1000
# 8901/8901 - 28s - loss: 0.4647 - accuracy: 0.4457 - 28s/epoch - 3ms/step
# Epoch 68/1000
# 8901/8901 - 28s - loss: 0.4639 - accuracy: 0.4465 - 28s/epoch - 3ms/step
# Epoch 69/1000
# 8901/8901 - 27s - loss: 0.4642 - accuracy: 0.4454 - 27s/epoch - 3ms/step
# Epoch 70/1000
# 8901/8901 - 27s - loss: 0.4637 - accuracy: 0.4459 - 27s/epoch - 3ms/step
# Epoch 71/1000
# 8901/8901 - 28s - loss: 0.4635 - accuracy: 0.4452 - 28s/epoch - 3ms/step
# Epoch 72/1000
# 8901/8901 - 27s - loss: 0.4638 - accuracy: 0.4447 - 27s/epoch - 3ms/step
# Epoch 73/1000
# 8901/8901 - 27s - loss: 0.4633 - accuracy: 0.4451 - 27s/epoch - 3ms/step
# Epoch 74/1000
# 8901/8901 - 27s - loss: 0.4633 - accuracy: 0.4444 - 27s/epoch - 3ms/step
# Epoch 75/1000
# 8901/8901 - 28s - loss: 0.4638 - accuracy: 0.4455 - 28s/epoch - 3ms/step
# Epoch 76/1000
# 8901/8901 - 27s - loss: 0.4640 - accuracy: 0.4440 - 27s/epoch - 3ms/step
# Epoch 77/1000
# 8901/8901 - 27s - loss: 0.4638 - accuracy: 0.4441 - 27s/epoch - 3ms/step
# Epoch 78/1000
# 8901/8901 - 27s - loss: 0.4635 - accuracy: 0.4436 - 27s/epoch - 3ms/step
# Epoch 79/1000
# 8901/8901 - 28s - loss: 0.4637 - accuracy: 0.4442 - 28s/epoch - 3ms/step
# Epoch 80/1000
# 8901/8901 - 27s - loss: 0.4631 - accuracy: 0.4429 - 27s/epoch - 3ms/step
# Epoch 81/1000
# 8901/8901 - 27s - loss: 0.4629 - accuracy: 0.4433 - 27s/epoch - 3ms/step
# Epoch 82/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-7ccc6a31f9d9> in <cell line: 1>()
# ----> 1 history= model.fit(X, X,
#       2           epochs=1000,
#       3           batch_size =32,
#       4           callbacks=[es],
#       5           verbose=2)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# **This is taking too long to train > 30 min**

# %% [markdown]
# ## Results analysis
# After training is done, we make predictions for the complete dataset and inspect the reconstruction loss. Our assumption is that, higher reconstruction loss are more likely to belong to anomalies than lower reconstruciton loss.

# %%
preds = model.predict(X)
errs  = np.square(preds-X)
errs  = np.mean(errs,axis=1)
# Out:
# 8901/8901 [==============================] - 14s 2ms/step

# %%
plt.figure(figsize=(16,10))
rng = np.arange(len(errs))
colors = ['g','r'] # green: normal, red: anomaly
for i in [0,1]:
    plt.scatter(rng[(Y==i).reshape(-1)], errs[(Y==i).reshape(-1)], color=colors[i])

# %%
Y_cut    = Y[errs<10]
errs_cut = errs[errs<10]

# %%
plt.figure(figsize=(16,10))
rng = np.arange(len(errs_cut))
colors = ['g','r'] 
for i in [0,1]:
    plt.scatter(rng[(Y_cut==i).reshape(-1)], errs_cut[(Y_cut==i).reshape(-1)], color=colors[i])

# %% [markdown]
# ## Exercise 4: finding the right treshold
# Find a treshold that identifies at least 130 anomalies correctly with as small number of missclassifications of non-anomalies as possible.

# %%
treshold = 3.9
errs_filtered               = errs[errs>treshold]
Y_filtered                  = Y[errs>treshold]
errs_filtered_non_anomalies = errs[errs<=treshold]
Y_filtered_non_anomalies    = Y[errs<=treshold]

print("Anomalies in the dataset") # Y_filtered==1
print("   predicted as anomaly:", len(errs_filtered[Y_filtered==1]))
print("   predicted as non-anomaly: ", len(errs_filtered_non_anomalies[Y_filtered_non_anomalies==1]) )
print("Non-anomalies in the dataset") # Y_filtered ==0
print("   predicted as anomaly:", len(errs_filtered[Y_filtered==0]))
print("   predicted as non-anomaly:", len(errs_filtered_non_anomalies[Y_filtered_non_anomalies==0]) )
# Out:
# Anomalies in the dataset
#    predicted as anomaly: 133
#    predicted as non-anomaly:  359
# Non-anomalies in the dataset
#    predicted as anomaly: 2755
#    predicted as non-anomaly: 281560

# %% [markdown]
# We can also inspect the confusion matrix:

# %%
from sklearn.metrics import confusion_matrix
conf=confusion_matrix(Y, errs>treshold)
import seaborn as sns
sns.heatmap(conf, annot=True, vmax=8000, fmt="d")
# Out:
# <Axes: >
